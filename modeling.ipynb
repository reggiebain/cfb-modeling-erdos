# %% [markdown]
# # Modeling

# %% [markdown]
# ### Regression
# - We treat the data as a set of features at the start of each year and regress on varoius outcomes

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data/working_df.csv')
df.head()
# Out:
#             team  team_id  year     conference  games_played  expected_wins  \
# 0      Air Force     2005  2014  Mountain West            13            9.7
# 1          Akron     2006  2014   Mid-American            12            5.4
# 2        Alabama      333  2014            SEC            14           11.7
# 3        Arizona       12  2014         Pac-12            14            8.8
# 4  Arizona State        9  2014         Pac-12            13            9.7
#
#    wins  losses     elo     fpi  ...  def_drives  off_explode  def_explode  \
# 0    10       3  1071.0 -16.682  ...         137     0.860561     0.902638
# 1     5       7  1121.0 -12.121  ...         156     0.973352     0.952424
# 2    12       2  2114.0  28.891  ...         150     0.915606     0.912426
# 3    10       4  1652.0  13.168  ...         173     0.848512     0.930193
# 4    10       3  1823.0  21.855  ...         189     0.905857     1.075455
#
# ...

# %%
from sklearn.model_selection import train_test_split

# Split into 20% test/val, 80% train
train, test = train_test_split(df.copy(), random_state = 123, shuffle = True, train_size = 0.8)

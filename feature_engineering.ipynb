# %% [markdown]
# # Feature Engineering
# - In this notebook, we calculate some features that have to do with the "talent level" of a team. This is captured to some unknown (due to proprietary algorithm) degree in the FPI, but can be more explicitely calculated using the recruiting ratings as we will see below.
# - We will also calculate blue chip ratios using recruiting rankings. This is the fraction of a roster that is 4 and 5 star recruits. For many teams, this value is 0, but for the top 50 or so teams, this is correlated substantively with win percentage.

# %%
#!pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/envs/erdos_may_2024/lib/python3.11/site-packages (from plotly) (8.3.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/erdos_may_2024/lib/python3.11/site-packages (from plotly) (24.0)
# Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 8.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: plotly
# Successfully installed plotly-5.22.0

# %%
# Get general dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
player_info_df = pd.read_csv('data/team_info.csv')
team_recruiting_df = pd.read_csv('data/team_recruiting.csv')
player_recruiting_df = pd.read_csv('data/player_recruiting.csv').rename(columns={'school': 'team'})

# %% [markdown]
# ### Individual Player Recruiting Rankings

# %% [markdown]
# We'll stick with data from 2007 on since that's where 247Sports Composite ranking reliably ranked most recruits to major teams.

# %%
# Filter out non FBS teams
fbs_teams = player_info_df['team'].tolist()
team_recruiting_df = team_recruiting_df[team_recruiting_df['team'].isin(fbs_teams)]

# Keep years from 2007 on when rankings reliable
team_recruiting_df = team_recruiting_df[team_recruiting_df['year'] >= 2007]
team_recruiting_df.head()
# Out:
#           team  year  rank  points
# 782    Florida  2007     1  313.05
# 783        USC  2007     2  295.06
# 784      Texas  2007     3  293.10
# 785  Tennessee  2007     4  284.42
# 786        LSU  2007     5  282.25

# %%
player_recruiting_df = player_recruiting_df[player_recruiting_df['year'] >= 2007]
player_recruiting_df.head()
# Out:
#                 name  year  star            team state  ranking  rating
# 10573   Joe McKnight  2007     5             USC    LA      1.0  0.9997
# 10574  Jimmy Clausen  2007     5      Notre Dame    CA      2.0  0.9987
# 10575     Eric Berry  2007     5       Tennessee    GA      3.0  0.9985
# 10576  Marvin Austin  2007     5  North Carolina    DC      4.0  0.9977
# 10577   Ryan Mallett  2007     5        Michigan    TX      5.0  0.9976

# %% [markdown]
# ### Rolling average of 4 recruiting classes for each team

# %%
# Calculate rolling average of team recruiting class rating
team_recruiting_df['talent_level'] = team_recruiting_df.groupby(by=['team'])['points'].rolling(window=4, min_periods=4).mean().reset_index(level=0, drop=True)

# There will be some NaN values. Count them
print(f"There are {team_recruiting_df[team_recruiting_df.year == 2010]['talent_level'].isna().sum()} null values in 2010")

# Fill these null values with talent level of 0
team_recruiting_df['talent_level'] = team_recruiting_df['talent_level'].fillna(0)

# Keep only records from 2010 where we'll have non zero talent level
#team_recruiting_2010_df = team_recruiting_df[team_recruiting_df['year'] >= 2010].copy()

team_recruiting_df
# Out:
# There are 7 null values in 2010
#                   team  year  rank  points  talent_level
# 782            Florida  2007     1  313.05        0.0000
# 783                USC  2007     2  295.06        0.0000
# 784              Texas  2007     3  293.10        0.0000
# 785          Tennessee  2007     4  284.42        0.0000
# 786                LSU  2007     5  282.25        0.0000
# ...                ...   ...   ...     ...           ...
# 4064  New Mexico State  2024   134   67.75      107.0550
# 4080              Army  2024   152   37.76       74.3475
# 4081              Navy  2024   153   37.64       69.4150
# 4099         Air Force  2024   172   23.21      102.0175
# 4124        New Mexico  2024   201   10.22       86.9000
#
# [2318 rows x 5 columns]

# %% [markdown]
# ### Blue Chip Ratios for Each Team
# - Start using data in 2007 to calculate BCR in 2010 and beyond

# %%
blue_chip_counts = player_recruiting_df[player_recruiting_df.star >= 4].groupby(['year','team'])['star'].size()
total_player_counts = player_recruiting_df.groupby(['year','team'])['star'].size()
# Out:
# year  team
# 2007  Alabama          6
#       Arizona          1
#       Arizona State    1
#       Arkansas         1
#       Auburn           8
# Name: star, dtype: int64

# %%
blue_chip_df = team_recruiting_df.merge(blue_chip_counts, 
                    how='left', on=['year', 'team']).merge(total_player_counts, 
                                                           how='left', on=['year', 'team'])
blue_chip_df = blue_chip_df.rename(columns={'star_x': 'blue_chip', 'star_y': 'total'})
blue_chip_df[['blue_chip', 'total']] = blue_chip_df[['blue_chip', 'total']].fillna(0)
blue_chip_df
# Out:
#                   team  year  rank  points  talent_level  blue_chip  total
# 0              Florida  2007     1  313.05        0.0000       18.0   23.0
# 1                  USC  2007     2  295.06        0.0000       14.0   18.0
# 2                Texas  2007     3  293.10        0.0000       16.0   24.0
# 3            Tennessee  2007     4  284.42        0.0000       10.0   27.0
# 4                  LSU  2007     5  282.25        0.0000       14.0   24.0
# ...                ...   ...   ...     ...           ...        ...    ...
# 2313  New Mexico State  2024   134   67.75      107.0550        0.0    0.0
# 2314              Army  2024   152   37.76       74.3475        0.0    0.0
# 2315              Navy  2024   153   37.64       69.4150        0.0    0.0
# 2316         Air Force  2024   172   23.21      102.0175        0.0    0.0
# 2317        New Mexico  2024   201   10.22       86.9000        0.0    0.0
#
# [2318 rows x 7 columns]

# %%
# Calculate running sums for blue chip ratio
blue_chip_df['blue_sums'] = blue_chip_df.groupby('team')['blue_chip'].rolling(window=4, min_periods=4).sum().reset_index(level=0, drop=True)
blue_chip_df['total_sums'] = blue_chip_df.groupby('team')['total'].rolling(window=4, min_periods=4).sum().reset_index(level=0, drop=True)
blue_chip_df['blue_chip_ratio'] = blue_chip_df['blue_sums']/blue_chip_df['total_sums']

# Filter out until after 2010 to get relevant results
blue_chip_2010_df = blue_chip_df[(blue_chip_df.year >= 2010) ].copy()
blue_chip_2010_df['blue_chip_ratio'] = blue_chip_2010_df['blue_chip_ratio'].fillna(0)

blue_chip_2010_df
# Out:
#                   team  year  rank  points  talent_level  blue_chip  total  \
# 346            Florida  2010     1  324.62      298.5900       22.0   28.0
# 347              Texas  2010     2  312.07      288.4725       21.0   24.0
# 348                USC  2010     3  294.73      292.3525       15.0   17.0
# 349            Alabama  2010     4  284.20      276.5550       14.0   22.0
# 350           Oklahoma  2010     5  283.58      262.9475       17.0   30.0
# ...                ...   ...   ...     ...           ...        ...    ...
# 2313  New Mexico State  2024   134   67.75      107.0550        0.0    0.0
# 2314              Army  2024   152   37.76       74.3475        0.0    0.0
# 2315              Navy  2024   153   37.64       69.4150        0.0    0.0
# 2316         Air Force  2024   172   23.21      102.0175        0.0    0.0
# 2317        New Mexico  2024   201   10.22       86.9000        0.0    0.0
#
#       blue_sums  total_sums  blue_chip_ratio
# 346        64.0        83.0         0.771084
# 347        67.0        88.0         0.761364
# 348        57.0        70.0         0.814286
# 349        61.0       100.0         0.610000
# 350        46.0        88.0         0.522727
# ...         ...         ...              ...
# 2313        0.0        31.0         0.000000
# 2314        0.0        61.0         0.000000
# 2315        0.0        39.0         0.000000
# 2316        0.0        75.0         0.000000
# 2317        0.0        41.0         0.000000
#
# [1972 rows x 10 columns]

# %%
# Check results for known team
blue_chip_2010_df[blue_chip_2010_df.team == 'Ohio State']
# Out:
#             team  year  rank  points  talent_level  blue_chip  total  \
# 363   Ohio State  2010    18  237.38      229.8300       10.0   16.0
# 472   Ohio State  2011     6  278.47      267.2025       13.0   25.0
# 597   Ohio State  2012     5  286.13      270.9775       16.0   23.0
# 725   Ohio State  2013     2  303.35      276.3325       19.0   24.0
# 858   Ohio State  2014     3  296.08      291.0075       16.0   23.0
# 995   Ohio State  2015     7  279.60      291.2900       15.0   26.0
# 1125  Ohio State  2016     4  289.12      292.0375       17.0   25.0
# 1256  Ohio State  2017     2  312.14      294.2350       19.0   22.0
# 1389  Ohio State  2018     2  317.06      299.4800       22.0   26.0
# 1534  Ohio State  2019    14  261.18      294.8750       12.0   17.0
# 1658  Ohio State  2020     5  295.08      296.3650       18.0   26.0
# 1788  Ohio State  2021     2  309.49      295.7025       18.0   21.0
# 1923  Ohio State  2022     4  300.95      291.6750       20.0   21.0
# 2056  Ohio State  2023     5  288.98      298.6250       20.0   22.0
# 2189  Ohio State  2024     5  289.13      297.1375        0.0    0.0
#
#       blue_sums  total_sums  blue_chip_ratio
# 363        44.0        61.0         0.721311
# 472        52.0        80.0         0.650000
# 597        55.0        89.0         0.617978
# 725        58.0        88.0         0.659091
# 858        64.0        95.0         0.673684
# 995        66.0        96.0         0.687500
# 1125       67.0        98.0         0.683673
# 1256       67.0        96.0         0.697917
# 1389       73.0        99.0         0.737374
# 1534       70.0        90.0         0.777778
# 1658       71.0        91.0         0.780220
# 1788       70.0        90.0         0.777778
# 1923       68.0        85.0         0.800000
# 2056       76.0        90.0         0.844444
# 2189       58.0        64.0         0.906250

# %%
blue_chip_2010_df.to_csv('data/team_recruiting_w_blue_chip_ratios.csv', index=False)

# %% [markdown]
# ### Coaching Prior Win Pct
# - Calculate the cumulative win percentage of each coach over their career leading up to a particular season

# %%
coaches_df = pd.read_csv('data/coaches.csv')
coaches_df.head()
# Out:
#          name               team  year  games  wins  losses
# 0  Eli Abbott            Alabama  1902      8     4       4
# 1  Earl Abell            Colgate  1928      9     6       3
# 2  Earl Abell           Virginia  1929      9     4       3
# 3  Earl Abell           Virginia  1930     10     4       6
# 4   Earl Able  Mississippi State  1923      9     5       2

# %%
coaches_df.year.max()
# Out:
# 2023

# %%
coaches_df = coaches_df.sort_values(by='year').copy()
# Group by name and create rolling average up to a given year.
coaches_df['cumulative_wins'] = coaches_df.groupby('name')['wins'].cumsum()
coaches_df['cumulative_games'] = coaches_df.groupby('name')['games'].cumsum()
coaches_df['career_win_pct'] = coaches_df['cumulative_wins']/coaches_df['cumulative_games']

# Fill Null values with 0 for new head coaches in a given year
coaches_df['career_win_pct'] = coaches_df['career_win_pct'].fillna(0)

# %%
coaches_df.to_csv('data/coach_career_win_pct.csv', index=False)

# %% [markdown]
# ### Turnover Margin and Total TDs Calculation
# - Use traditional stats to calculate total turover margin

# %%
trad_stats_df = pd.read_csv('data/season_stats.csv')
trad_stats_df.columns
# Out:
# Index(['team', 'year', 'conference', 'firstDowns', 'fourthDownConversions',
#        'fourthDowns', 'fumblesLost', 'fumblesRecovered', 'games',
#        'interceptionTDs', 'interceptionYards', 'interceptions',
#        'kickReturnTDs', 'kickReturnYards', 'kickReturns', 'netPassingYards',
#        'passAttempts', 'passCompletions', 'passesIntercepted', 'passingTDs',
#        'penalties', 'penaltyYards', 'possessionTime', 'puntReturnTDs',
#        'puntReturnYards', 'puntReturns', 'rushingAttempts', 'rushingTDs',
#        'rushingYards', 'sacks', 'tacklesForLoss', 'thirdDownConversions',
#        'thirdDowns', 'totalYards', 'turnovers'],
#       dtype='object')

# %%
# Calculate turnover margin
trad_stats_df['turnover_margin'] = trad_stats_df['passesIntercepted'] + trad_stats_df['fumblesRecovered'] - trad_stats_df['turnovers']
# Calculate total tds scored
trad_stats_df['total_tds'] = trad_stats_df['passingTDs'] + trad_stats_df['rushingTDs']

# %%
trad_stats_df.to_csv('data/season_stats_w_totals.csv', index=False)

# %% [markdown]
# ### Win Percentage (Target) and Rolling Win Percentage Calculation
# - Target win percentage calculation
# - 4 year window of win percentage for a program

# %%
records_df = pd.read_csv('data/team_records_by_year.csv')

records_df
# Out:
#                   team  team_id  year      conference  games_played  \
# 0            Air Force     2005  2000   Mountain West            12
# 1                Akron     2006  2000    Mid-American            11
# 2              Alabama      333  2000             SEC            11
# 3              Arizona       12  2000          Pac-10            11
# 4        Arizona State        9  2000          Pac-10            12
# ...                ...      ...   ...             ...           ...
# 2944  Western Kentucky       98  2023  Conference USA            13
# 2945  Western Michigan     2711  2023    Mid-American            12
# 2946     West Virginia      277  2023          Big 12            13
# 2947         Wisconsin      275  2023         Big Ten            13
# 2948           Wyoming     2751  2023   Mountain West            13
#
#       expected_wins  wins  losses  home_wins  home_losses  away_wins  \
# 0               0.0     9       3          5            1          3
# 1               0.0     6       5          3            3          3
# 2               0.0     3       8          3            3          0
# 3               0.0     5       6          2            4          3
# 4               0.0     6       6          3            3          3
# ...             ...   ...     ...        ...          ...        ...
# 2944            6.2     8       5          4            2          3
# 2945            4.5     4       8          3            2          1
# 2946            8.8     9       4          5            1          3
# 2947            6.4     7       6          4            3          3
# 2948            7.3     9       4          7            0          1
#
#       away_losses
# 0               2
# 1               2
# 2               5
# 3               2
# 4               2
# ...           ...
# 2944            3
# 2945            6
# 2946            3
# 2947            2
# 2948            4
#
# [2949 rows x 12 columns]

# %%
# Calculate win pct
records_df['win_pct'] = records_df['wins']/records_df['games_played']

# Calculate running previous win pct
records_df['cumulative_wins'] = records_df.groupby('team')['wins'].cumsum()
records_df['cumulative_games'] = records_df.groupby('team')['games_played'].cumsum()
records_df['recent_win_pct'] = records_df['cumulative_wins']/records_df['cumulative_games']

# Fill Null values with 0 for new head coaches in a given year
records_df['recent_win_pct'] = records_df['recent_win_pct'].fillna(0)

records_df[records_df.team=='South Carolina'].head()
# Out:
#                team  team_id  year conference  games_played  expected_wins  \
# 83   South Carolina     2579  2000        SEC            12            0.0
# 198  South Carolina     2579  2001        SEC            12            0.0
# 314  South Carolina     2579  2002        SEC            12            0.0
# 430  South Carolina     2579  2003        SEC            12            0.0
# 546  South Carolina     2579  2004        SEC            11            0.0
#
#      wins  losses  home_wins  home_losses  away_wins  away_losses   win_pct  \
# 83      8       4          5            1          2            3  0.666667
# 198     9       3          7            1          2            2  0.750000
# 314     5       7          3            3          2            4  0.416667
# 430     5       7          5            3          0            4  0.416667
# 546     6       5          3            3          3            2  0.545455
#
#      cumulative_wins  cumulative_games  recent_win_pct
# 83                 8                12        0.666667
# 198               17                24        0.708333
# 314               22                36        0.611111
# 430               27                48        0.562500
# 546               33                59        0.559322

# %%
records_calcs_df = records_df[['team', 'year', 'conference', 'expected_wins', 'win_pct', 'recent_win_pct']].copy()
records_calcs_df.to_csv('data/records_by_year_calcs.csv', index=False)

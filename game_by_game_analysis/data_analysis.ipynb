# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #### Merge all dataframes from years 2002-2024 together.

# %%
games_df = pd.concat([pd.read_csv("game_by_game_stats/games_"+str(year)+".csv") 
                      for year in range(2024, 2001, -1)])

# %%
games_df
# Out:
#     Unnamed: 0           id            team1  team1_pts team1_home_away  \
# 0            0  401540244.0            Lamar       17.0            home
# 1            1  401525434.0             Navy        3.0            away
# 2            2  401525435.0  Tennessee State        3.0            away
# 3            3  401520154.0        UT Martin        7.0            away
# 4            4  401520176.0             Utah       24.0            home
# ..         ...          ...              ...        ...             ...
# 666        666  243392426.0             Army       13.0            away
# 667        667  243380058.0       Pittsburgh       43.0            away
# 668        668  243392390.0    Virginia Tech       16.0            away
# 669        669  243392655.0       Louisville       55.0            away
# 670        670  243392572.0       California       26.0            away
#
#      team1_rushingTDs  team1_passingTDs  team1_kickReturnYards  \
# 0                 1.0               1.0                   82.0
# 1                 0.0               0.0                   12.0
# 2                 0.0               0.0                   76.0
# 3                 0.0               1.0                    7.0
# 4                 2.0               1.0                   16.0
# ..                ...               ...                    ...
# 666               0.0               2.0                    NaN
# 667               0.0               5.0                    NaN
# 668               0.0               2.0                    NaN
# 669               5.0               1.0                    NaN
# 670               1.0               2.0                    NaN
#
#      team1_kickReturnTDs  team1_kickReturns  ...  team1_passesDeflected  \
# 0                    0.0                4.0  ...                    NaN
# 1                    0.0                1.0  ...                    2.0
# 2                    0.0                2.0  ...                    1.0
# 3                    0.0                1.0  ...                    3.0
# 4                    0.0                1.0  ...                    4.0
# ..                   ...                ...  ...                    ...
# 666                  NaN                NaN  ...                    NaN
# 667                  NaN                NaN  ...                    NaN
# 668                  NaN                NaN  ...                    NaN
# 669                  NaN                NaN  ...                    NaN
# 670                  NaN                NaN  ...                    NaN
#
#      team2_tacklesForLoss  team2_defensiveTDs  team2_tackles  team2_sacks  \
# 0                     NaN                 NaN            NaN          NaN
# 1                     5.0                 0.0           41.0          2.0
# 2                     5.0                 1.0           32.0          1.0
# 3                     4.0                 1.0           28.0          1.0
# 4                     4.0                 0.0           29.0          0.0
# ..                    ...                 ...            ...          ...
# 666                   NaN                 NaN            NaN          NaN
# 667                   NaN                 NaN            NaN          NaN
# 668                   NaN                 NaN            NaN          NaN
# 669                   NaN                 NaN            NaN          NaN
# 670                   NaN                 NaN            NaN          NaN
#
#      team2_qbHurries team2_passesDeflected  team1_puntReturnYards  \
# 0                NaN                   NaN                    NaN
# 1                2.0                   0.0                    NaN
# 2               10.0                   4.0                    NaN
# 3                0.0                   2.0                    NaN
# 4                2.0                   2.0                    5.0
# ..               ...                   ...                    ...
# 666              NaN                   NaN                   20.0
# 667              NaN                   NaN                   22.0
# 668              NaN                   NaN                   16.0
# 669              NaN                   NaN                   18.0
# 670              NaN                   NaN                    0.0
#
#      team1_puntReturnTDs  team1_puntReturns
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4                    0.0                3.0
# ..                   ...                ...
# 666                  0.0                3.0
# 667                  0.0                3.0
# 668                  0.0                4.0
# 669                  0.0                6.0
# 670                  0.0                5.0
#
# [17007 rows x 78 columns]

# %%
dates_df = pd.concat([pd.read_csv("game_by_game_stats/game_dates"+str(year)+".csv") 
                      for year in range(2024, 2001, -1)])

# %%
dates_df
# Out:
#      Unnamed: 0         id                      date       home_team  \
# 0             0  401643858  2024-08-24T04:00:00.000Z         Hawai'i
# 1             1  401643696  2024-08-24T04:00:00.000Z          Nevada
# 2             2  401643697  2024-08-24T04:00:00.000Z      New Mexico
# 3             3  401635525  2024-08-24T16:00:00.000Z    Georgia Tech
# 4             4  401643698  2024-08-29T04:00:00.000Z  San José State
# ..          ...        ...                       ...             ...
# 739         739  223410276  2002-12-07T19:30:00.000Z        Marshall
# 740         740  223410026  2002-12-07T21:30:00.000Z            UCLA
# 741         741  223410008  2002-12-07T23:00:00.000Z        Arkansas
# 742         742  223410038  2002-12-08T01:00:00.000Z        Colorado
# 743         743  223410062  2002-12-08T04:05:00.000Z         Hawai'i
#
#             away_team  home_pregame_elo  away_pregame_elo conference_game  \
# 0      Delaware State               NaN               NaN           False
# 1                 SMU               NaN               NaN           False
# 2       Montana State               NaN               NaN           False
# 3       Florida State               NaN               NaN            True
# 4    Sacramento State               NaN               NaN           False
# ..                ...               ...               ...             ...
# 739            Toledo            1642.0            1697.0            True
# 740  Washington State            1688.0            1777.0            True
# 741           Georgia            1765.0            1932.0            True
# 742          Oklahoma            1782.0            2087.0            True
# 743   San Diego State            1603.0            1297.0           False
#
#     season_type home_division away_division
# 0       regular           fbs           fcs
# 1       regular           fbs           fbs
# 2       regular           fbs           fcs
# 3       regular           fbs           fbs
# 4       regular           fbs           fcs
# ..          ...           ...           ...
# 739     regular           fbs           fbs
# 740     regular           fbs           fbs
# 741     regular           fbs           fbs
# 742     regular           fbs           fbs
# 743     regular           fbs           fbs
#
# [36265 rows x 11 columns]

# %%
print(games_df.isna().sum().to_string())
# Out:
# Unnamed: 0                       0
# id                               0
# team1                            0
# team1_pts                        0
# team1_home_away                  0
# team1_rushingTDs                 7
# team1_passingTDs                37
# team1_kickReturnYards         4624
# team1_kickReturnTDs           4624
# team1_kickReturns             4624
# team1_kickingPoints            529
# team1_interceptionYards       7494
# team1_interceptionTDs         7494
# team1_passesIntercepted       7494
# team1_fumblesRecovered           8
# team1_totalFumbles           11337
# team1_possessionTime            37
# team1_interceptions              5
# team1_fumblesLost                5
# team1_turnovers                  5
# team1_totalPenaltiesYards        5
# team1_yardsPerRushAttempt        5
# team1_rushingAttempts            5
# team1_rushingYards               5
# team1_yardsPerPass               5
# team1_completionAttempts         5
# team1_netPassingYards            5
# team1_totalYards                 5
# team1_fourthDownEff              5
# team1_thirdDownEff               5
# team1_firstDowns                 5
# team2                            0
# team2_pts                        0
# team2_home_away                  0
# team2_rushingTDs                 9
# team2_puntReturnYards         3259
# team2_puntReturnTDs           3259
# team2_puntReturns             3259
# team2_passingTDs                45
# team2_kickReturnYards         4927
# team2_kickReturnTDs           4927
# team2_kickReturns             4927
# team2_kickingPoints            257
# team2_interceptionYards       6897
# team2_interceptionTDs         6897
# team2_passesIntercepted       6897
# team2_fumblesRecovered           5
# team2_totalFumbles           11307
# team2_possessionTime            27
# team2_interceptions              8
# team2_fumblesLost                8
# team2_turnovers                  8
# team2_totalPenaltiesYards        8
# team2_yardsPerRushAttempt        8
# team2_rushingAttempts            8
# team2_rushingYards               8
# team2_yardsPerPass               8
# team2_completionAttempts         8
# team2_netPassingYards            8
# team2_totalYards                 8
# team2_fourthDownEff              8
# team2_thirdDownEff               8
# team2_firstDowns                 8
# team1_tacklesForLoss         10584
# team1_defensiveTDs           10584
# team1_tackles                10584
# team1_sacks                  10584
# team1_qbHurries              10584
# team1_passesDeflected        10584
# team2_tacklesForLoss         10580
# team2_defensiveTDs           10580
# team2_tackles                10580
# team2_sacks                  10580
# team2_qbHurries              10580
# team2_passesDeflected        10580
# team1_puntReturnYards         4308
# team1_puntReturnTDs           4308
# team1_puntReturns             4308

# %% [markdown]
# #### Delete columns with > 100 missing entries and the column Unnamed: 0

# %%
num_to_drop = games_df.shape[0]-99
games_df.dropna(thresh = num_to_drop, axis=1, inplace=True)
games_df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
dates_df.drop("Unnamed: 0", axis=1, inplace=True)

# %% [markdown]
# #### Merge games_df and dates_df according to game id.

# %%
games_df.id = games_df.id.apply(int)
merged_df = games_df.merge(dates_df, on="id", how="inner")

team1_home = (merged_df.team1 == merged_df.home_team)
team2_home = (merged_df.team2 == merged_df.home_team)
team1_away = (merged_df.team1 == merged_df.away_team)
team2_away = (merged_df.team2 == merged_df.away_team)

merged_df["team1_pregame_elo"] = (team1_home)*merged_df.home_pregame_elo \
                                + (team1_away)*merged_df.away_pregame_elo
merged_df["team2_pregame_elo"] = (team2_home)*merged_df.home_pregame_elo \
                                + (team2_away)*merged_df.away_pregame_elo

merged_df.drop(["home_pregame_elo", "away_pregame_elo"], axis=1, inplace=True)

# %%
#Sanity Check

print((team1_home == team2_away).all()) #Should be true.
print((team1_away == team2_home).all()) #Should be true.
print(((team1_home & team2_away) | (team1_away & team2_home)).all()) #Should be true.
# Out:
# True
# True
# True

# %% [markdown]
# #### Format the date as datetime.date for each game and sort by date.

# %%
from datetime import date
merged_df.date = merged_df.date.str.split("T", expand=True)[0]
merged_df["year"] = merged_df.date.str.split("-", expand=True)[0].apply(int)

def get_date(date_str) :
    ymd = date_str.split("-")
    return date(int(ymd[0]), int(ymd[1]), int(ymd[2]))

merged_df.date = merged_df.date.apply(get_date)

# %%
merged_df = merged_df.sort_values(by="date").reset_index()
merged_df.index = merged_df.id
merged_df.drop("index", axis=1, inplace=True)

# %% [markdown]
# #### Drop columns not needed.

# %%
columns_to_drop = ["home_team",
                  "away_team",
                  "team1_passingTDs",
                  "team1_fumblesRecovered",
                  "team1_possessionTime",
                  "team1_totalPenaltiesYards",
                  "team2_passingTDs",
                  "team2_fumblesRecovered",
                  "team2_possessionTime",
                  "team2_totalPenaltiesYards",
                  "team1_rushingTDs",
                  "team2_rushingTDs"]

merged_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
merged_df.columns
# Out:
# Index(['id', 'team1', 'team1_pts', 'team1_home_away', 'team1_interceptions',
#        'team1_fumblesLost', 'team1_turnovers', 'team1_yardsPerRushAttempt',
#        'team1_rushingAttempts', 'team1_rushingYards', 'team1_yardsPerPass',
#        'team1_completionAttempts', 'team1_netPassingYards', 'team1_totalYards',
#        'team1_fourthDownEff', 'team1_thirdDownEff', 'team1_firstDowns',
#        'team2', 'team2_pts', 'team2_home_away', 'team2_interceptions',
#        'team2_fumblesLost', 'team2_turnovers', 'team2_yardsPerRushAttempt',
#        'team2_rushingAttempts', 'team2_rushingYards', 'team2_yardsPerPass',
#        'team2_completionAttempts', 'team2_netPassingYards', 'team2_totalYards',
#        'team2_fourthDownEff', 'team2_thirdDownEff', 'team2_firstDowns', 'date',
#        'conference_game', 'season_type', 'home_division', 'away_division',
#        'team1_pregame_elo', 'team2_pregame_elo', 'year'],
#       dtype='object')

# %% [markdown]
# #### Drop teams which have < 200 games played in the last 20 years.

# %%
teams_to_drop = (pd.concat([merged_df.team1, merged_df.team2]).value_counts() < 200)
teams_to_drop = teams_to_drop[teams_to_drop].index

# %%
rows_to_drop = [ind for ind in merged_df.index 
                if (merged_df.loc[ind].team1 in teams_to_drop) 
                    | (merged_df.loc[ind].team2 in teams_to_drop)]

# %%
merged_df.drop(rows_to_drop, axis=0, inplace=True)

# %%
merged_df[merged_df.isna().any(axis=1)]
# Out:
#                   id    team1  team1_pts team1_home_away  team1_interceptions  \
# id
# 401506450  401506450  Buffalo       23.0            home                  NaN
#
#            team1_fumblesLost  team1_turnovers  team1_yardsPerRushAttempt  \
# id
# 401506450                NaN              NaN                        NaN
#
#            team1_rushingAttempts  team1_rushingYards  ...  team2_thirdDownEff  \
# id                                                    ...
# 401506450                    NaN                 NaN  ...                 NaN
#
#           team2_firstDowns        date  conference_game season_type  \
# id
# 401506450              NaN  2022-12-02             True     regular
#
#           home_division  away_division team1_pregame_elo  team2_pregame_elo  \
# id
# 401506450           fbs            fbs            1389.0             1147.0
#
#            year
# id
# 401506450  2022
#
# [1 rows x 41 columns]

# %% [markdown]
# There are only one game with NaN values which we fill in manually.

# %%
merged_df.loc[401506450, "team1_netPassingYards"] = 264
merged_df.loc[401506450, "team1_rushingYards"] = 27
merged_df.loc[401506450, "team1_firstDowns"] = 18
merged_df.loc[401506450, "team1_thirdDownEff"] = "2-15"
merged_df.loc[401506450, "team1_fourthDownEff"] = "3-5"
merged_df.loc[401506450, "team1_fumblesLost"] = 1
merged_df.loc[401506450, "team1_interceptions"] = 2

merged_df.loc[401506450, "team2_netPassingYards"] = 254
merged_df.loc[401506450, "team2_rushingYards"] = 52
merged_df.loc[401506450, "team2_firstDowns"] = 20
merged_df.loc[401506450, "team2_thirdDownEff"] = "7-17"
merged_df.loc[401506450, "team2_fourthDownEff"] = "0-0"
merged_df.loc[401506450, "team2_fumblesLost"] = 1
merged_df.loc[401506450, "team2_interceptions"] = 1

# Data obtained from google.com

# %% [markdown]
# #### We delete the columns "totalYards" as this should be a sum of "netPassingYards" and "rushingYards".

# %%
merged_df.drop(["team1_totalYards", "team2_totalYards"], axis=1, inplace=True)

# %% [markdown]
# #### Determining whether 0 passing yards is missing data by grabbing stats from ESPN.

# %%
import requests
from bs4 import BeautifulSoup


def get_team_stats_espn(game_id) :
    url = "https://www.espn.com/college-football/matchup/_/gameId/" + str(game_id)
    head = headers={
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
                       AppleWebKit/537.36 (KHTML, like Gecko) \
                       Chrome/116.0.0.0 Safari/537.36"
    }

    req = requests.get(url, headers=head)

    if(req.status_code != 200) :
        return None

    stat_dict = dict()
    soup = BeautifulSoup(req.text, "html.parser")
    
    teams = [e.text for e in soup.find_all("h2", 
                        {"class" : "ScoreCell__TeamName"})]
    stat_dict["teams"] = teams
    
    table = soup.find("section", attrs={"class" : "Card TeamStatsTable"})
    for entry in table.find_all("tr") :
        name = entry.find("td")
        if(name == None) :
            continue
        stat_dict[name.text] = []
        for el in entry.find_all("td")[1:] :
            stat_dict[name.text].append(el.text)
            
    return stat_dict

def get_stats_for_games_ids_espn(game_ids) :
    stats_df = pd.DataFrame()
    for game_id in game_ids :
        df = pd.DataFrame(get_team_stats_espn(game_id))
        for t in range(1,3) :
            stats_df.loc[game_id, "team"+str(t)] = df.loc[t-1, "teams"]
            stats_df.loc[game_id, "team"+str(t)+"_firstDowns"] = int(df.loc[t-1, "1st Downs"])
            stats_df.loc[game_id, "team"+str(t)+"_thirdDownEff"] = df.loc[t-1, "3rd down efficiency"]
            stats_df.loc[game_id, "team"+str(t)+"_fourthDownEff"] = df.loc[t-1, "4th down efficiency"]
            stats_df.loc[game_id, "team"+str(t)+"_netPassingYards"] = int(df.loc[t-1, "Passing"])
            stats_df.loc[game_id, "team"+str(t)+"_yardsPerPass"] = float(df.loc[t-1, "Yards per pass"])
            stats_df.loc[game_id, "team"+str(t)+"_interceptions"] = int(df.loc[t-1, "Interceptions thrown"])
            stats_df.loc[game_id, "team"+str(t)+"_completionAttempts"] = df.loc[t-1, "Comp-Att"]
            stats_df.loc[game_id, "team"+str(t)+"_fumblesLost"] = int(df.loc[t-1, "Fumbles lost"])
            stats_df.loc[game_id, "team"+str(t)+"_turnovers"] = int(df.loc[t-1, "Turnovers"])
            stats_df.loc[game_id, "team"+str(t)+"_yardsPerRushAttempt"] = float(df.loc[t-1, "Yards per rush"])
            stats_df.loc[game_id, "team"+str(t)+"_rushingAttempts"] = int(df.loc[t-1, "Rushing Attempts"])
            stats_df.loc[game_id, "team"+str(t)+"_rushingYards"] = int(df.loc[t-1, "Rushing"])
    return stats_df

# %%
stats = get_stats_for_games_ids_espn([401506450])

# %%
stats.columns
# Out:
# Index(['team1', 'team1_firstDowns', 'team1_thirdDownEff',
#        'team1_fourthDownEff', 'team1_netPassingYards', 'team1_yardsPerPass',
#        'team1_interceptions', 'team1_completionAttempts', 'team1_fumblesLost',
#        'team1_turnovers', 'team1_yardsPerRushAttempt', 'team1_rushingAttempts',
#        'team1_rushingYards', 'team2', 'team2_firstDowns', 'team2_thirdDownEff',
#        'team2_fourthDownEff', 'team2_netPassingYards', 'team2_yardsPerPass',
#        'team2_interceptions', 'team2_completionAttempts', 'team2_fumblesLost',
#        'team2_turnovers', 'team2_yardsPerRushAttempt', 'team2_rushingAttempts',
#        'team2_rushingYards'],
#       dtype='object')

# %%
for c in stats.columns :
    if((c == "team1") | (c == "team2")) :
        continue
    col = c.split("_")[1]
    merged_df.loc[401506450, "team1_"+col] = stats.loc[401506450, "team2_"+col]
    merged_df.loc[401506450, "team2_"+col] = stats.loc[401506450, "team1_"+col]

# %% [markdown]
# #### Convert strings to numerical data.

# %% [markdown]
# Convert third and fourth down efficiencies to columns containing total downs and number of successfully converted downs.

# %%
for team in ["team1_", "team2_"]:
    for down in ["thirdDown", "fourthDown"] :
        downs = merged_df[team+down+"Eff"].str.split("-", expand=True)
        merged_df[team+"converted"+down+"s"] = downs[0].apply(int)
        merged_df[team+"total"+down+"s"] = downs[1].apply(int)
        
merged_df.drop(["team1_thirdDownEff", "team2_thirdDownEff", "team1_fourthDownEff", "team2_fourthDownEff"], axis=1, inplace=True)

# %% [markdown]
# Convert completionAttempts to two columns of completions and attempts.

# %%
for team in ["team1_", "team2_"]:
    compAtt = merged_df[team+"completionAttempts"].str.split("-", expand=True)
    merged_df[team+"passCompletes"] = compAtt[0].apply(int)
    merged_df[team+"passAttempts"] = compAtt[1].apply(int)

merged_df.drop(["team1_completionAttempts", "team2_completionAttempts"], axis=1, inplace=True)

# %% [markdown]
# #### Replace home or away strings with +1 or 0.

# %%
merged_df.team1_home_away = (merged_df.team1_home_away == "home").apply(int)
merged_df.team2_home_away = (merged_df.team2_home_away == "home").apply(int)

# %%
for c in merged_df.loc[:, merged_df.columns[33:]] :
    merged_df[c] = pd.to_numeric(merged_df[c])

# %% [markdown]
# #### Add average performance of prior games.

# %%
def rolling_mean_stat(col, team_name) :
    team1_select = (merged_df.team1 == team_name)
    team2_select = (merged_df.team2 == team_name)
    team_df = merged_df[team1_select | team2_select]
    team1_select = (team_df.team1 == team_name)
    team2_select = (team_df.team2 == team_name)
    
    rolling_df = pd.DataFrame(index = team_df.index, columns=["def_"+col, "off_"+col])
    
    rolling_df["def_"+col] \
        = ((team1_select)*team_df["team2_"+col] + (team2_select)*team_df["team1_"+col]) \
          .rolling(4, min_periods=1).mean()
    rolling_df["off_"+col] \
        = ((team1_select)*team_df["team1_"+col] + (team2_select)*team_df["team2_"+col]) \
          .rolling(4, min_periods=1).mean()
        
    return rolling_df.shift(1)

# %%
for c in merged_df.columns:
    print(c)
# Out:
# id
# team1
# team1_pts
# team1_home_away
# team1_interceptions
# team1_fumblesLost
# team1_turnovers
# team1_yardsPerRushAttempt
# team1_rushingAttempts
# team1_rushingYards
# team1_yardsPerPass
# team1_netPassingYards
# team1_firstDowns
# team2
# team2_pts
# team2_home_away
# team2_interceptions
# team2_fumblesLost
# team2_turnovers
# team2_yardsPerRushAttempt
# team2_rushingAttempts
# team2_rushingYards
# team2_yardsPerPass
# team2_netPassingYards
# team2_firstDowns
# date
# conference_game
# season_type
# home_division
# away_division
# team1_pregame_elo
# team2_pregame_elo
# year
# team1_convertedthirdDowns
# team1_totalthirdDowns
# team1_convertedfourthDowns
# team1_totalfourthDowns
# team2_convertedthirdDowns
# team2_totalthirdDowns
# team2_convertedfourthDowns
# team2_totalfourthDowns
# team1_passCompletes
# team1_passAttempts
# team2_passCompletes
# team2_passAttempts

# %%
features = ["interceptions",
           "turnovers",
           "yardsPerRushAttempt",
           "yardsPerPass",
            "rushingYards",
           "netPassingYards",
            "firstDowns",
            "convertedthirdDowns",
            "totalthirdDowns",
            "convertedfourthDowns",
            "totalfourthDowns",
            "passCompletes",
            "passAttempts"
           ]

teams = pd.concat([merged_df.team1, merged_df.team2]).unique()

for col in features :
    dict_of_team_stats = {team : rolling_mean_stat(col, team) for team in teams}
    
    for i in merged_df.id :
        team1_name = merged_df.loc[i, "team1"]
        team2_name = merged_df.loc[i, "team2"]
        
        for pos in ["off_", "def_"] :
            merged_df.loc[i, "team1_"+pos+col] = dict_of_team_stats[team1_name].loc[i, pos+col]
            merged_df.loc[i, "team2_"+pos+col] = dict_of_team_stats[team2_name].loc[i, pos+col]

# %% [markdown]
# #### Include blue chip ratios.

# %%
merged_df
# Out:
#                   id          team1  team1_pts  team1_home_away  \
# id
# 242410259  242410259  Virginia Tech       13.0                1
# 242460254  242460254           Utah       41.0                1
# 242462050  242462050     Ball State       11.0                1
# 242460009  242460009           UTEP        9.0                0
# 242462628  242462628            TCU       48.0                1
# ...              ...            ...        ...              ...
# 401539482  401539482           UNLV       20.0                1
# 401539481  401539481         Toledo       14.0                1
# 401539480  401539480           Iowa        0.0                1
# 401539478  401539478     Louisville        6.0                0
# 401520445  401520445           Navy       11.0                0
#
#            team1_interceptions  team1_fumblesLost  team1_turnovers  \
# id
# 242410259                  1.0                2.0              3.0
# 242460254                  0.0                0.0              0.0
# 242462050                  0.0                0.0              0.0
# 242460009                  4.0                1.0              5.0
# 242462628                  1.0                1.0              2.0
# ...                        ...                ...              ...
# 401539482                  2.0                1.0              3.0
# 401539481                  1.0                1.0              2.0
# 401539480                  0.0                3.0              3.0
# 401539478                  1.0                0.0              1.0
# 401520445                  1.0                1.0              2.0
#
#            team1_yardsPerRushAttempt  team1_rushingAttempts  \
# id
# 242410259                        4.1                   34.0
# 242460254                        4.7                   45.0
# 242462050                        1.9                   33.0
# 242460009                        2.8                   31.0
# 242462628                        4.4                   36.0
# ...                              ...                    ...
# 401539482                        2.9                   28.0
# 401539481                        3.3                   29.0
# 401539480                        1.5                   24.0
# 401539478                        2.3                   34.0
# 401520445                        3.7                   35.0
#
#            team1_rushingYards  ...  team1_def_totalfourthDowns  \
# id                             ...
# 242410259               141.0  ...                         NaN
# 242460254               212.0  ...                         NaN
# 242462050                64.0  ...                         NaN
# 242460009                87.0  ...                         NaN
# 242462628               157.0  ...                         NaN
# ...                       ...  ...                         ...
# 401539482                81.0  ...                        1.00
# 401539481                97.0  ...                        3.50
# 401539480                35.0  ...                        0.75
# 401539478                77.0  ...                        1.75
# 401520445               130.0  ...                        1.75
#
#            team2_def_totalfourthDowns  team1_off_passCompletes  \
# id
# 242410259                         NaN                      NaN
# 242460254                         NaN                      NaN
# 242462050                         NaN                      NaN
# 242460009                         NaN                      NaN
# 242462628                         NaN                      NaN
# ...                               ...                      ...
# 401539482                        2.00                    16.25
# 401539481                        2.50                    16.00
# 401539480                        1.50                    15.00
# 401539478                        1.25                    19.75
# 401520445                        2.25                     8.00
#
#           team2_off_passCompletes  team1_def_passCompletes  \
# id
# 242410259                     NaN                      NaN
# 242460254                     NaN                      NaN
# 242462050                     NaN                      NaN
# 242460009                     NaN                      NaN
# 242462628                     NaN                      NaN
# ...                           ...                      ...
# 401539482                   14.00                    13.50
# 401539481                    9.50                    16.50
# 401539480                   15.00                    14.00
# 401539478                   19.25                    17.25
# 401520445                    7.25                    23.50
#
#            team2_def_passCompletes  team1_off_passAttempts  \
# id
# 242410259                      NaN                     NaN
# 242460254                      NaN                     NaN
# 242462050                      NaN                     NaN
# 242460009                      NaN                     NaN
# 242462628                      NaN                     NaN
# ...                            ...                     ...
# 401539482                     16.5                   25.25
# 401539481                     17.0                   23.25
# 401539480                     15.5                   25.75
# 401539478                     10.0                   27.75
# 401520445                     10.5                   15.00
#
#            team2_off_passAttempts  team1_def_passAttempts  \
# id
# 242410259                     NaN                     NaN
# 242460254                     NaN                     NaN
# 242462050                     NaN                     NaN
# 242460009                     NaN                     NaN
# 242462628                     NaN                     NaN
# ...                           ...                     ...
# 401539482                   25.00                   22.25
# 401539481                   17.00                   34.75
# 401539480                   22.25                   28.25
# 401539478                   32.50                   29.00
# 401520445                   13.75                   34.00
#
#            team2_def_passAttempts
# id
# 242410259                     NaN
# 242460254                     NaN
# 242462050                     NaN
# 242460009                     NaN
# 242462628                     NaN
# ...                           ...
# 401539482                   28.50
# 401539481                   29.25
# 401539480                   28.00
# 401539478                   24.50
# 401520445                   20.25
#
# [12627 rows x 97 columns]

# %%
print(merged_df[merged_df.year > 2004].columns)
# Out:
# Index(['id', 'team1', 'team1_pts', 'team1_home_away', 'team1_interceptions',
#        'team1_fumblesLost', 'team1_turnovers', 'team1_yardsPerRushAttempt',
#        'team1_rushingAttempts', 'team1_rushingYards', 'team1_yardsPerPass',
#        'team1_netPassingYards', 'team1_firstDowns', 'team2', 'team2_pts',
#        'team2_home_away', 'team2_interceptions', 'team2_fumblesLost',
#        'team2_turnovers', 'team2_yardsPerRushAttempt', 'team2_rushingAttempts',
#        'team2_rushingYards', 'team2_yardsPerPass', 'team2_netPassingYards',
#        'team2_firstDowns', 'date', 'conference_game', 'season_type',
#        'home_division', 'away_division', 'team1_pregame_elo',
#        'team2_pregame_elo', 'year', 'team1_convertedthirdDowns',
#        'team1_totalthirdDowns', 'team1_convertedfourthDowns',
#        'team1_totalfourthDowns', 'team2_convertedthirdDowns',
#        'team2_totalthirdDowns', 'team2_convertedfourthDowns',
#        'team2_totalfourthDowns', 'team1_passCompletes', 'team1_passAttempts',
#        'team2_passCompletes', 'team2_passAttempts', 'team1_off_interceptions',
#        'team2_off_interceptions', 'team1_def_interceptions',
#        'team2_def_interceptions', 'team1_off_turnovers', 'team2_off_turnovers',
#        'team1_def_turnovers', 'team2_def_turnovers',
#        'team1_off_yardsPerRushAttempt', 'team2_off_yardsPerRushAttempt',
#        'team1_def_yardsPerRushAttempt', 'team2_def_yardsPerRushAttempt',
#        'team1_off_yardsPerPass', 'team2_off_yardsPerPass',
#        'team1_def_yardsPerPass', 'team2_def_yardsPerPass',
#        'team1_off_rushingYards', 'team2_off_rushingYards',
#        'team1_def_rushingYards', 'team2_def_rushingYards',
#        'team1_off_netPassingYards', 'team2_off_netPassingYards',
#        'team1_def_netPassingYards', 'team2_def_netPassingYards',
#        'team1_off_firstDowns', 'team2_off_firstDowns', 'team1_def_firstDowns',
#        'team2_def_firstDowns', 'team1_off_convertedthirdDowns',
#        'team2_off_convertedthirdDowns', 'team1_def_convertedthirdDowns',
#        'team2_def_convertedthirdDowns', 'team1_off_totalthirdDowns',
#        'team2_off_totalthirdDowns', 'team1_def_totalthirdDowns',
#        'team2_def_totalthirdDowns', 'team1_off_convertedfourthDowns',
#        'team2_off_convertedfourthDowns', 'team1_def_convertedfourthDowns',
#        'team2_def_convertedfourthDowns', 'team1_off_totalfourthDowns',
#        'team2_off_totalfourthDowns', 'team1_def_totalfourthDowns',
#        'team2_def_totalfourthDowns', 'team1_off_passCompletes',
#        'team2_off_passCompletes', 'team1_def_passCompletes',
#        'team2_def_passCompletes', 'team1_off_passAttempts',
#        'team2_off_passAttempts', 'team1_def_passAttempts',
#        'team2_def_passAttempts'],
#       dtype='object')

# %% [markdown]
# # Model Selection

# %%
# Baseline model : predict the team with the higher pregame_elo will win.
# The predicted probability that team1 will win is 1 if team1 has a higher pregame_elo.

class HigherELOWins :
    def __init__(self) :
        return
    def fit(self, X, y) :
        return self
    def predict(self, X) :
        return (X.team1_pregame_elo > X.team2_pregame_elo)
    def score(self, X, y) :
        return (self.predict(X) == y).sum()/y.shape[0]
    def predict_proba(self, X) :
        res = np.array(self.predict(X).apply(int))
        return np.stack((1-res, res), axis=1)
    def get_params(self, *args, **kwargs) :
        return {}

# %%
X_columns = ['team1_home_away', 'team2_home_away', 'team1_pregame_elo',
       'team2_pregame_elo', 'team1_off_interceptions',
       'team2_off_interceptions', 'team1_def_interceptions',
       'team2_def_interceptions', 'team1_off_turnovers', 'team2_off_turnovers',
       'team1_def_turnovers', 'team2_def_turnovers',
       'team1_off_yardsPerRushAttempt', 'team2_off_yardsPerRushAttempt',
       'team1_def_yardsPerRushAttempt', 'team2_def_yardsPerRushAttempt',
       'team1_off_yardsPerPass', 'team2_off_yardsPerPass',
       'team1_def_yardsPerPass', 'team2_def_yardsPerPass',
       'team1_off_rushingYards', 'team2_off_rushingYards',
       'team1_def_rushingYards', 'team2_def_rushingYards',
       'team1_off_netPassingYards', 'team2_off_netPassingYards',
       'team1_def_netPassingYards', 'team2_def_netPassingYards',
       'team1_off_firstDowns', 'team2_off_firstDowns', 'team1_def_firstDowns',
       'team2_def_firstDowns', 'team1_off_convertedthirdDowns',
       'team2_off_convertedthirdDowns', 'team1_def_convertedthirdDowns',
       'team2_def_convertedthirdDowns', 'team1_off_totalthirdDowns',
       'team2_off_totalthirdDowns', 'team1_def_totalthirdDowns',
       'team2_def_totalthirdDowns', 'team1_off_convertedfourthDowns',
       'team2_off_convertedfourthDowns', 'team1_def_convertedfourthDowns',
       'team2_def_convertedfourthDowns', 'team1_off_totalfourthDowns',
       'team2_off_totalfourthDowns', 'team1_def_totalfourthDowns',
       'team2_def_totalfourthDowns', 'team1_off_passCompletes',
       'team2_off_passCompletes', 'team1_def_passCompletes',
       'team2_def_passCompletes', 'team1_off_passAttempts',
       'team2_off_passAttempts', 'team1_def_passAttempts']
X_train = merged_df[(merged_df.year>2004) & (merged_df.year < 2020)][X_columns]
y_train = (merged_df[(merged_df.year>2004) & (merged_df.year < 2020)].team1_pts \
           > merged_df[(merged_df.year>2004) & (merged_df.year < 2020)].team2_pts)
X_test = merged_df[merged_df.year>=2020][X_columns]
y_test = (merged_df[merged_df.year>=2020].team1_pts > merged_df[merged_df.year>=2020].team2_pts)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

models = {
    "Baseline Model" : HigherELOWins(),
    "Logistic Regression" : LogisticRegression(max_iter=10000),
    "Decision Tree" : DecisionTreeClassifier(max_depth=100, max_leaf_nodes=6),
    "Gradient Boost" : GradientBoostingClassifier(loss='log_loss'),
    "Random Forest" : RandomForestClassifier(n_estimators=100, max_depth=100, max_leaf_nodes=6, random_state=1)
}

def probability_mse(estimator, X, y) :
    return 1-mean_squared_error(estimator.predict_proba(X)[:,1], y.apply(int))

scores = dict()
for key, value in models.items() :
    scores[key] = cross_val_score(value, X_train, y_train, scoring=probability_mse).mean()
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fig, ax = plt.subplots()

ax.bar(scores.keys(), scores.values(), label=scores.keys())

ax.set_ylabel('MSE')
ax.set_title('MSE Scores of Different Models')

plt.show()

# %% [markdown]
# #### Fit data to full training set and predict 2020 games.

# %%
scores_2020 = dict()
merged_df_2020 = merged_df[merged_df.year==2020]
X_2020 = merged_df_2020[X_columns]
y_2020 = (merged_df_2020.team1_pts > merged_df_2020.team2_pts)
for key, value in models.items() :
    value.fit(X_train, y_train)
    scores_2020[key] = probability_mse(value, X_2020, y_2020)

# %%
scores_2020
# Out:
# {'Baseline Model': 0.7188940092165899,
#  'Logistic Regression': 0.8141887961552348,
#  'Decision Tree': 0.7828012048466031,
#  'Gradient Boost': 0.8091422658435548,
#  'Random Forest': 0.7843967991451507}

# %% [markdown]
# Logistic Regression appears to generalize best of the five models.
